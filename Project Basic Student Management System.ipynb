# %%
registeredName = "SALTUKHAN"
registeredSurname = "GULSEN"

print("Welcome student information platform \nPlease give your information")

name = input("Name : ")
surname = input("Surname : ")

nameUpper = name.upper()
surnameUpper = surname.upper()
changes = 2
int(changes)


if registeredName == nameUpper and registeredSurname == surnameUpper:
    print(f'Welcome {nameUpper}')

    
elif registeredName != nameUpper or registeredSurname != surnameUpper:
    
    while 1 <= changes < 4:            

        if registeredName != nameUpper or registeredSurname != surnameUpper:
            print("Wrong name or surname please try again\nLast", changes," changes!!" )
            changes = changes - 1
            name = input("Name : ")
            surname = input("Surname : ")
            nameUpper = name.upper()
            surnameUpper = surname.upper()
        elif registeredName == nameUpper and registeredSurname == surnameUpper:
            break
        
    if registeredName == nameUpper and registeredSurname == surnameUpper:
        print(f'Welcome {nameUpper}')
    elif registeredName != nameUpper or registeredSurname != surnameUpper:
        print("Please try again later...")
        
lessons = ["Pyhsic","Math","Chemistry","Introduction to engineering","Algorithm and Programming"]
print(f'available courses :{lessons}' )

#I can't fixed about I could not find how to enter a warning on the screen if the course you selected is not on the list

lessonsNumber = int(input("How many lessons do you want to choose"))
if lessonsNumber < 3:
    print("You fail because you didn't choose enough lessons")
elif lessonsNumber == 3:
    lesson1 = input("First Lesson : ")
    i1 = lessons.index(lesson1)
    print(f'You have one correct lesson {i1}')
    lesson2 = input("Second Lesson :")
    i2 = lessons.index(lesson2)
    print(f'You have one correct lesson {i2}')
    lesson3 = input("Third Lesson : ")
    i3 = lessons.index(lesson3)
    print(f'You have one correct lesson {i3}')
elif lessonsNumber == 4:
    lesson1 = input("First Lesson : ")
    i1 = lessons.index(lesson1)
    print(f'You have one correct lesson {i1}')
    lesson2 = input("Second Lesson :")
    i2 = lessons.index(lesson2)
    print(f'You have one correct lesson {i2}')
    lesson3 = input("Third Lesson : ")
    i3 = lessons.index(lesson3)
    print(f'You have one correct lesson {i3}')
    lesson4 = input("fourth Lesson :")
    i4 = lessons.index(lesson4)
    print(f'You have one correct lesson {i4}')
elif lessonsNumber == 5:
    lesson1 = input("First Lesson : ")
    i1 = lessons.index(lesson1)
    print(f'You have one correct lesson {i1}')
    lesson2 = input("Second Lesson :")
    i2 = lessons.index(lesson2)
    print(f'You have one correct lesson {i2}')
    lesson3 = input("Third Lesson : ")
    i3 = lessons.index(lesson3)
    print(f'You have one correct lesson {i3}')
    lesson4 = input("fourth Lesson :")
    i4 = lessons.index(lesson4)
    print(f'You have one correct lesson {i4}')
    lesson5 = input("fifth Lesson :")
    i5 = lessons.index(lesson5)
    print(f'You have one correct lesson {i5}')
        
print("If you enter your exams value, you can see your grade")        
        
midtermExam = int(input("Midterm exam result : "))
if midtermExam > 100:
    print("Your value is wrong")
midterm = midtermExam*0.3
final = int(input("Final exam result : "))
if final > 100:
    print("Your value is wrong")
final = final*0.5
project = int(input("Project result : "))
if project > 100:
    print("Your value is wrong")
project = project*0.2


totalScore = final + project + midterm
print(totalScore)

if 101 > totalScore > 90:
    print("AA")
elif 90 > totalScore > 70:
    print("BB")
elif 70 > totalScore > 50:
    print("CC")
elif 50 > totalScore > 30:
    print("DD")
elif 30 > totalScore >= 0:
    print("FF")
else:
    print("Your value is wrong")
# Out:
# Welcome student information platform
# Please give your information
# Name : saltsdf
# Surname : sdgas
# Wrong name or surname please try again
# Last 2  changes!!
# Name : saltukhan
# Surname : gulsen
# Welcome SALTUKHAN
# available courses :['Pyhsic', 'Math', 'Chemistry', 'Introduction to engineering', 'Algorithm and Programming']
# How many lessons do you want to choose3
# First Lesson : Pyhsic
# You have one correct lesson 0
# Second Lesson :Math
# You have one correct lesson 1
# Third Lesson : Chemistry
# You have one correct lesson 2
# If you enter your exams value, you can see your grade
# Midterm exam result : 70
# Final exam result : 80
# Project result : 50
# 71.0
# BB
